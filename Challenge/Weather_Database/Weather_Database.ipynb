# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import requests

from config import weather_api_key

from datetime import datetime

import gmaps 

from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

coordinates = list(lat_lngs)

# %%
from citipy import citipy 



# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Country": city_country,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dwarka
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | pangoa
# Processing Record 4 of Set 1 | mar del plata
# Processing Record 5 of Set 1 | noumea
# Processing Record 6 of Set 1 | honningsvag
# Processing Record 7 of Set 1 | buin
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | sansai
# City not found. Skipping...
# Processing Record 10 of Set 1 | gelemso
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | carnarvon
# Processing Record 14 of Set 1 | raudeberg
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | impfondo
# Processing Record 18 of Set 1 | biu
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | sokolo
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | high level
# Processing Record 24 of Set 1 | aranos
# Processing Record 25 of Set 1 | bathsheba
# Processing Record 26 of Set 1 | bali
# Processing Record 27 of Set 1 | thompson
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | marovoay
# Processing Record 31 of Set 1 | nanpiao
# Processing Record 32 of Set 1 | ribeira grande
# Processing Record 33 of Set 1 | hermanus
# Processing Record 34 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 1 | clyde river
# Processing Record 36 of Set 1 | jujuy
# City not found. Skipping...
# Processing Record 37 of Set 1 | holme
# Processing Record 38 of Set 1 | kemise
# Processing Record 39 of Set 1 | omsukchan
# Processing Record 40 of Set 1 | beloha
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | mount gambier
# Processing Record 43 of Set 1 | dong hoi
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | ulaanbaatar
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | burnie
# Processing Record 48 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | labuhan
# Processing Record 1 of Set 2 | klaksvik
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | labuan
# Processing Record 4 of Set 2 | progreso
# Processing Record 5 of Set 2 | mocajuba
# Processing Record 6 of Set 2 | hofn
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | avera
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | burica
# City not found. Skipping...
# Processing Record 11 of Set 2 | sabzevar
# Processing Record 12 of Set 2 | pangnirtung
# Processing Record 13 of Set 2 | leshukonskoye
# Processing Record 14 of Set 2 | belyy yar
# Processing Record 15 of Set 2 | makurdi
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | bluff
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | arraial do cabo
# Processing Record 20 of Set 2 | sistranda
# Processing Record 21 of Set 2 | kesennuma
# City not found. Skipping...
# Processing Record 22 of Set 2 | fonte boa
# Processing Record 23 of Set 2 | soyo
# Processing Record 24 of Set 2 | maldonado
# Processing Record 25 of Set 2 | malinovskiy
# Processing Record 26 of Set 2 | korem
# Processing Record 27 of Set 2 | tuatapere
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | manokwari
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | tevaitoa
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | chuy
# Processing Record 34 of Set 2 | bonavista
# Processing Record 35 of Set 2 | castro
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | gravdal
# Processing Record 38 of Set 2 | richards bay
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | coquimbo
# Processing Record 42 of Set 2 | kondinskoye
# Processing Record 43 of Set 2 | atuona
# Processing Record 44 of Set 2 | kiruna
# Processing Record 45 of Set 2 | ketchikan
# Processing Record 46 of Set 2 | bosaso
# Processing Record 47 of Set 2 | kautokeino
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | bethel
# Processing Record 50 of Set 2 | trinidad
# Processing Record 1 of Set 3 | vostok
# Processing Record 2 of Set 3 | dingle
# Processing Record 3 of Set 3 | codrington
# Processing Record 4 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 3 | lagoa
# Processing Record 6 of Set 3 | vila franca do campo
# Processing Record 7 of Set 3 | longyearbyen
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | garissa
# Processing Record 10 of Set 3 | stokmarknes
# Processing Record 11 of Set 3 | mitsamiouli
# Processing Record 12 of Set 3 | gizo
# Processing Record 13 of Set 3 | port alfred
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | nikolskoye
# Processing Record 16 of Set 3 | faanui
# Processing Record 17 of Set 3 | inirida
# Processing Record 18 of Set 3 | lom sak
# Processing Record 19 of Set 3 | inuvik
# Processing Record 20 of Set 3 | henties bay
# Processing Record 21 of Set 3 | almeirim
# Processing Record 22 of Set 3 | tecoanapa
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | verkhnevilyuysk
# Processing Record 25 of Set 3 | ladario
# Processing Record 26 of Set 3 | saint peter
# Processing Record 27 of Set 3 | kushmurun
# Processing Record 28 of Set 3 | sagua la grande
# Processing Record 29 of Set 3 | san rafael del sur
# Processing Record 30 of Set 3 | port-gentil
# Processing Record 31 of Set 3 | deputatskiy
# Processing Record 32 of Set 3 | pacific grove
# Processing Record 33 of Set 3 | saint anthony
# Processing Record 34 of Set 3 | anuradhapura
# Processing Record 35 of Set 3 | rocha
# Processing Record 36 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 3 | barrow
# Processing Record 38 of Set 3 | rudbar
# Processing Record 39 of Set 3 | hamilton
# Processing Record 40 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 41 of Set 3 | pasca
# Processing Record 42 of Set 3 | nenjiang
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | rabo de peixe
# Processing Record 45 of Set 3 | pak phanang
# Processing Record 46 of Set 3 | namibe
# Processing Record 47 of Set 3 | campina verde
# Processing Record 48 of Set 3 | hovd
# Processing Record 49 of Set 3 | smidovich
# Processing Record 50 of Set 3 | vitimskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | husavik
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | aguimes
# Processing Record 6 of Set 4 | oranjemund
# Processing Record 7 of Set 4 | assiniboia
# Processing Record 8 of Set 4 | limanu
# Processing Record 9 of Set 4 | mahebourg
# Processing Record 10 of Set 4 | pacifica
# Processing Record 11 of Set 4 | cape town
# Processing Record 12 of Set 4 | tuktoyaktuk
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | margate
# Processing Record 15 of Set 4 | monrovia
# Processing Record 16 of Set 4 | luderitz
# Processing Record 17 of Set 4 | aksarka
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | college
# Processing Record 20 of Set 4 | sao filipe
# Processing Record 21 of Set 4 | lerwick
# Processing Record 22 of Set 4 | dunedin
# Processing Record 23 of Set 4 | keskin
# Processing Record 24 of Set 4 | port hardy
# Processing Record 25 of Set 4 | geraldton
# Processing Record 26 of Set 4 | kedougou
# Processing Record 27 of Set 4 | blagoyevo
# Processing Record 28 of Set 4 | xai-xai
# Processing Record 29 of Set 4 | porto nacional
# Processing Record 30 of Set 4 | viedma
# Processing Record 31 of Set 4 | chardara
# Processing Record 32 of Set 4 | upernavik
# Processing Record 33 of Set 4 | vestmannaeyjar
# Processing Record 34 of Set 4 | sao joao da barra
# Processing Record 35 of Set 4 | saint-philippe
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | gimli
# Processing Record 38 of Set 4 | murgab
# Processing Record 39 of Set 4 | cascais
# Processing Record 40 of Set 4 | uberlandia
# Processing Record 41 of Set 4 | luau
# Processing Record 42 of Set 4 | brae
# Processing Record 43 of Set 4 | pochutla
# Processing Record 44 of Set 4 | taltal
# Processing Record 45 of Set 4 | la rioja
# Processing Record 46 of Set 4 | kruisfontein
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | airai
# Processing Record 49 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 50 of Set 4 | fortuna
# Processing Record 1 of Set 5 | butembo
# Processing Record 2 of Set 5 | gat
# Processing Record 3 of Set 5 | neryungri
# Processing Record 4 of Set 5 | saldanha
# Processing Record 5 of Set 5 | port blair
# Processing Record 6 of Set 5 | victoria
# Processing Record 7 of Set 5 | bubaque
# Processing Record 8 of Set 5 | guerrero negro
# Processing Record 9 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 5 | lysyanka
# Processing Record 11 of Set 5 | ust-omchug
# Processing Record 12 of Set 5 | barranca
# Processing Record 13 of Set 5 | chapais
# Processing Record 14 of Set 5 | los llanos de aridane
# Processing Record 15 of Set 5 | avarua
# Processing Record 16 of Set 5 | chicama
# Processing Record 17 of Set 5 | lokosovo
# Processing Record 18 of Set 5 | solvychegodsk
# Processing Record 19 of Set 5 | chokurdakh
# Processing Record 20 of Set 5 | dudinka
# Processing Record 21 of Set 5 | hambantota
# Processing Record 22 of Set 5 | mehamn
# Processing Record 23 of Set 5 | west wendover
# Processing Record 24 of Set 5 | rio cuarto
# Processing Record 25 of Set 5 | acarau
# Processing Record 26 of Set 5 | killybegs
# Processing Record 27 of Set 5 | mozarlandia
# Processing Record 28 of Set 5 | asfi
# Processing Record 29 of Set 5 | todos santos
# Processing Record 30 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 5 | ewa beach
# Processing Record 32 of Set 5 | nishihara
# Processing Record 33 of Set 5 | saint-augustin
# Processing Record 34 of Set 5 | zverinogolovskoye
# Processing Record 35 of Set 5 | rawson
# Processing Record 36 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 37 of Set 5 | norman wells
# Processing Record 38 of Set 5 | kieta
# Processing Record 39 of Set 5 | esperance
# Processing Record 40 of Set 5 | ushibuka
# Processing Record 41 of Set 5 | san patricio
# Processing Record 42 of Set 5 | price
# Processing Record 43 of Set 5 | cervo
# Processing Record 44 of Set 5 | joensuu
# Processing Record 45 of Set 5 | inongo
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | port moresby
# Processing Record 48 of Set 5 | naze
# Processing Record 49 of Set 5 | anadyr
# Processing Record 50 of Set 5 | bajil
# Processing Record 1 of Set 6 | sangar
# Processing Record 2 of Set 6 | novoagansk
# Processing Record 3 of Set 6 | cururupu
# Processing Record 4 of Set 6 | talara
# Processing Record 5 of Set 6 | kangaatsiaq
# Processing Record 6 of Set 6 | roma
# Processing Record 7 of Set 6 | berdyuzhye
# City not found. Skipping...
# Processing Record 8 of Set 6 | novyy urengoy
# Processing Record 9 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 10 of Set 6 | saskylakh
# Processing Record 11 of Set 6 | torbay
# Processing Record 12 of Set 6 | kantang
# Processing Record 13 of Set 6 | stornoway
# Processing Record 14 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 6 | la ligua
# Processing Record 16 of Set 6 | phumi samraong
# City not found. Skipping...
# Processing Record 17 of Set 6 | nouadhibou
# Processing Record 18 of Set 6 | mount darwin
# Processing Record 19 of Set 6 | ankazoabo
# Processing Record 20 of Set 6 | koungou
# Processing Record 21 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 22 of Set 6 | maceio
# Processing Record 23 of Set 6 | shieli
# Processing Record 24 of Set 6 | seymchan
# Processing Record 25 of Set 6 | vrangel
# Processing Record 26 of Set 6 | gallup
# Processing Record 27 of Set 6 | saint george
# Processing Record 28 of Set 6 | toora-khem
# Processing Record 29 of Set 6 | genhe
# Processing Record 30 of Set 6 | kalmunai
# Processing Record 31 of Set 6 | sorland
# Processing Record 32 of Set 6 | conde
# Processing Record 33 of Set 6 | road town
# Processing Record 34 of Set 6 | portland
# Processing Record 35 of Set 6 | gogrial
# Processing Record 36 of Set 6 | egvekinot
# Processing Record 37 of Set 6 | sinnamary
# Processing Record 38 of Set 6 | pitimbu
# Processing Record 39 of Set 6 | kathmandu
# Processing Record 40 of Set 6 | piacabucu
# Processing Record 41 of Set 6 | weihai
# Processing Record 42 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 43 of Set 6 | trairi
# Processing Record 44 of Set 6 | rexburg
# Processing Record 45 of Set 6 | tasiilaq
# Processing Record 46 of Set 6 | bud
# Processing Record 47 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 6 | sorong
# Processing Record 49 of Set 6 | kahului
# Processing Record 50 of Set 6 | nome
# Processing Record 1 of Set 7 | mormugao
# Processing Record 2 of Set 7 | yulara
# Processing Record 3 of Set 7 | khash
# Processing Record 4 of Set 7 | sao geraldo do araguaia
# Processing Record 5 of Set 7 | luanda
# Processing Record 6 of Set 7 | carballo
# Processing Record 7 of Set 7 | escanaba
# Processing Record 8 of Set 7 | pionerskiy
# Processing Record 9 of Set 7 | juegang
# Processing Record 10 of Set 7 | cayenne
# Processing Record 11 of Set 7 | kirakira
# Processing Record 12 of Set 7 | turbat
# Processing Record 13 of Set 7 | la uribe
# City not found. Skipping...
# Processing Record 14 of Set 7 | sungaipenuh
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | san quintin
# Processing Record 17 of Set 7 | eureka
# Processing Record 18 of Set 7 | chumikan
# Processing Record 19 of Set 7 | ostrovnoy
# Processing Record 20 of Set 7 | te anau
# Processing Record 21 of Set 7 | tautira
# Processing Record 22 of Set 7 | skjervoy
# Processing Record 23 of Set 7 | gazli
# Processing Record 24 of Set 7 | maracaju
# Processing Record 25 of Set 7 | kovdor
# Processing Record 26 of Set 7 | batsfjord
# Processing Record 27 of Set 7 | khandyga
# Processing Record 28 of Set 7 | hasaki
# Processing Record 29 of Set 7 | awbari
# Processing Record 30 of Set 7 | chhagalnaiya
# Processing Record 31 of Set 7 | tiarei
# Processing Record 32 of Set 7 | umm lajj
# Processing Record 33 of Set 7 | asau
# Processing Record 34 of Set 7 | axim
# Processing Record 35 of Set 7 | sitka
# Processing Record 36 of Set 7 | lata
# Processing Record 37 of Set 7 | karratha
# Processing Record 38 of Set 7 | mount isa
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | shu
# Processing Record 41 of Set 7 | port elizabeth
# Processing Record 42 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 7 | saint-imier
# Processing Record 44 of Set 7 | emporia
# Processing Record 45 of Set 7 | goldap
# Processing Record 46 of Set 7 | springdale
# Processing Record 47 of Set 7 | ukiah
# Processing Record 48 of Set 7 | andros town
# Processing Record 49 of Set 7 | paamiut
# Processing Record 50 of Set 7 | biak
# Processing Record 1 of Set 8 | atar
# Processing Record 2 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 3 of Set 8 | narsaq
# Processing Record 4 of Set 8 | port hedland
# Processing Record 5 of Set 8 | horodkivka
# Processing Record 6 of Set 8 | ahipara
# Processing Record 7 of Set 8 | visnes
# Processing Record 8 of Set 8 | chifeng
# Processing Record 9 of Set 8 | aksu
# Processing Record 10 of Set 8 | ojuelos de jalisco
# Processing Record 11 of Set 8 | francisco sa
# Processing Record 12 of Set 8 | tutoia
# Processing Record 13 of Set 8 | vilyuysk
# Processing Record 14 of Set 8 | zhob
# Processing Record 15 of Set 8 | pisco
# Processing Record 16 of Set 8 | roald
# Processing Record 17 of Set 8 | biskamzha
# Processing Record 18 of Set 8 | pyshma
# Processing Record 19 of Set 8 | yichun
# Processing Record 20 of Set 8 | cidreira
# Processing Record 21 of Set 8 | dikson
# Processing Record 22 of Set 8 | barra da estiva
# Processing Record 23 of Set 8 | alice springs
# Processing Record 24 of Set 8 | suba
# Processing Record 25 of Set 8 | owando
# Processing Record 26 of Set 8 | souillac
# Processing Record 27 of Set 8 | kaya
# Processing Record 28 of Set 8 | mount pleasant
# Processing Record 29 of Set 8 | preobrazheniye
# Processing Record 30 of Set 8 | bereda
# Processing Record 31 of Set 8 | manzanillo
# Processing Record 32 of Set 8 | kaitangata
# Processing Record 33 of Set 8 | maxixe
# Processing Record 34 of Set 8 | saint-michel-des-saints
# Processing Record 35 of Set 8 | tateyama
# Processing Record 36 of Set 8 | yinchuan
# Processing Record 37 of Set 8 | planaltina
# Processing Record 38 of Set 8 | svetlaya
# Processing Record 39 of Set 8 | changchun
# Processing Record 40 of Set 8 | mae sot
# Processing Record 41 of Set 8 | touros
# Processing Record 42 of Set 8 | kiunga
# Processing Record 43 of Set 8 | ambon
# Processing Record 44 of Set 8 | verkh-usugli
# Processing Record 45 of Set 8 | quatre cocos
# Processing Record 46 of Set 8 | kaeo
# Processing Record 47 of Set 8 | baruun-urt
# Processing Record 48 of Set 8 | puerto narino
# Processing Record 49 of Set 8 | caravelas
# Processing Record 50 of Set 8 | male
# Processing Record 1 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 9 | santa rosa
# Processing Record 3 of Set 9 | yeppoon
# Processing Record 4 of Set 9 | sibolga
# Processing Record 5 of Set 9 | zeya
# Processing Record 6 of Set 9 | poltavka
# Processing Record 7 of Set 9 | wenling
# Processing Record 8 of Set 9 | roebourne
# Processing Record 9 of Set 9 | bilokurakyne
# Processing Record 10 of Set 9 | kuching
# Processing Record 11 of Set 9 | keningau
# Processing Record 12 of Set 9 | aklavik
# Processing Record 13 of Set 9 | dhidhdhoo
# Processing Record 14 of Set 9 | santa lucia
# Processing Record 15 of Set 9 | bistret
# Processing Record 16 of Set 9 | horsham
# Processing Record 17 of Set 9 | bongandanga
# Processing Record 18 of Set 9 | ponta delgada
# Processing Record 19 of Set 9 | bac lieu
# Processing Record 20 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 21 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 9 | chirgaon
# Processing Record 23 of Set 9 | zapolyarnyy
# Processing Record 24 of Set 9 | chara
# Processing Record 25 of Set 9 | esmeraldas
# Processing Record 26 of Set 9 | eloy
# Processing Record 27 of Set 9 | yilan
# Processing Record 28 of Set 9 | shellbrook
# Processing Record 29 of Set 9 | nanortalik
# Processing Record 30 of Set 9 | barra patuca
# Processing Record 31 of Set 9 | macon
# Processing Record 32 of Set 9 | broome
# Processing Record 33 of Set 9 | kamenka
# Processing Record 34 of Set 9 | katsuura
# Processing Record 35 of Set 9 | gamba
# Processing Record 36 of Set 9 | cabo san lucas
# Processing Record 37 of Set 9 | banjarmasin
# Processing Record 38 of Set 9 | buraydah
# Processing Record 39 of Set 9 | jiwani
# Processing Record 40 of Set 9 | buchanan
# Processing Record 41 of Set 9 | erdenet
# Processing Record 42 of Set 9 | halifax
# Processing Record 43 of Set 9 | san vicente
# Processing Record 44 of Set 9 | lhuntshi
# City not found. Skipping...
# Processing Record 45 of Set 9 | little current
# Processing Record 46 of Set 9 | les cayes
# Processing Record 47 of Set 9 | dharur
# Processing Record 48 of Set 9 | isangel
# Processing Record 49 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 50 of Set 9 | sambava
# Processing Record 1 of Set 10 | zheleznodorozhnyy
# Processing Record 2 of Set 10 | sola
# Processing Record 3 of Set 10 | lar gerd
# City not found. Skipping...
# Processing Record 4 of Set 10 | provideniya
# Processing Record 5 of Set 10 | gaya
# Processing Record 6 of Set 10 | jiaojiang
# Processing Record 7 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 10 | tabas
# Processing Record 9 of Set 10 | yanchukan
# City not found. Skipping...
# Processing Record 10 of Set 10 | uray
# Processing Record 11 of Set 10 | mahibadhoo
# Processing Record 12 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 10 | beringovskiy
# Processing Record 14 of Set 10 | cookshire
# City not found. Skipping...
# Processing Record 15 of Set 10 | ilulissat
# Processing Record 16 of Set 10 | san cristobal
# Processing Record 17 of Set 10 | inhambane
# Processing Record 18 of Set 10 | plettenberg bay
# Processing Record 19 of Set 10 | palmer
# Processing Record 20 of Set 10 | atkarsk
# Processing Record 21 of Set 10 | camacha
# Processing Record 22 of Set 10 | arawa
# Processing Record 23 of Set 10 | laje
# Processing Record 24 of Set 10 | hinton
# Processing Record 25 of Set 10 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 10 | boende
# Processing Record 27 of Set 10 | lompoc
# Processing Record 28 of Set 10 | ust-maya
# Processing Record 29 of Set 10 | el dorado
# Processing Record 30 of Set 10 | santa marta
# Processing Record 31 of Set 10 | werda
# Processing Record 32 of Set 10 | isny
# Processing Record 33 of Set 10 | nadym
# Processing Record 34 of Set 10 | kavieng
# Processing Record 35 of Set 10 | lander
# Processing Record 36 of Set 10 | guiyang
# Processing Record 37 of Set 10 | cape elizabeth
# City not found. Skipping...
# Processing Record 38 of Set 10 | kyabe
# Processing Record 39 of Set 10 | kamaishi
# Processing Record 40 of Set 10 | ternate
# Processing Record 41 of Set 10 | vangaindrano
# Processing Record 42 of Set 10 | sirvintos
# Processing Record 43 of Set 10 | kenai
# Processing Record 44 of Set 10 | kaabong
# Processing Record 45 of Set 10 | potosi
# Processing Record 46 of Set 10 | hamina
# Processing Record 47 of Set 10 | grants pass
# Processing Record 48 of Set 10 | annau
# Processing Record 49 of Set 10 | pongol
# Processing Record 50 of Set 10 | calabozo
# Processing Record 1 of Set 11 | tres arroyos
# Processing Record 2 of Set 11 | tiznit
# Processing Record 3 of Set 11 | amapa
# Processing Record 4 of Set 11 | sapao
# City not found. Skipping...
# Processing Record 5 of Set 11 | trostberg
# Processing Record 6 of Set 11 | jacareacanga
# Processing Record 7 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 11 | nantucket
# Processing Record 9 of Set 11 | antofagasta
# Processing Record 10 of Set 11 | arlit
# Processing Record 11 of Set 11 | punta alta
# Processing Record 12 of Set 11 | chunoyar
# Processing Record 13 of Set 11 | apple valley
# Processing Record 14 of Set 11 | bambous virieux
# Processing Record 15 of Set 11 | havre-saint-pierre
# Processing Record 16 of Set 11 | zhigansk
# Processing Record 17 of Set 11 | beidao
# Processing Record 18 of Set 11 | lima
# Processing Record 19 of Set 11 | denpasar
# Processing Record 20 of Set 11 | pervomayskoye
# Processing Record 21 of Set 11 | zelenogorskiy
# Processing Record 22 of Set 11 | kangavar
# Processing Record 23 of Set 11 | tougue
# Processing Record 24 of Set 11 | zhangjiakou
# Processing Record 25 of Set 11 | manado
# Processing Record 26 of Set 11 | comodoro rivadavia
# Processing Record 27 of Set 11 | marquette
# Processing Record 28 of Set 11 | abha
# Processing Record 29 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 11 | grindavik
# Processing Record 31 of Set 11 | pechenga
# Processing Record 32 of Set 11 | severomuysk
# Processing Record 33 of Set 11 | innisfail
# Processing Record 34 of Set 11 | maple creek
# Processing Record 35 of Set 11 | darnah
# Processing Record 36 of Set 11 | kloulklubed
# Processing Record 37 of Set 11 | acacoyagua
# Processing Record 38 of Set 11 | champerico
# Processing Record 39 of Set 11 | kavaratti
# Processing Record 40 of Set 11 | poum
# Processing Record 41 of Set 11 | murray bridge
# Processing Record 42 of Set 11 | ambilobe
# Processing Record 43 of Set 11 | fare
# Processing Record 44 of Set 11 | imbituba
# Processing Record 45 of Set 11 | hami
# Processing Record 46 of Set 11 | atlantic city
# Processing Record 47 of Set 11 | qasigiannguit
# Processing Record 48 of Set 11 | muzhi
# Processing Record 49 of Set 11 | kiama
# Processing Record 50 of Set 11 | lodeynoye pole
# Processing Record 1 of Set 12 | mandalgovi
# Processing Record 2 of Set 12 | rio gallegos
# Processing Record 3 of Set 12 | san ramon
# Processing Record 4 of Set 12 | mattru
# Processing Record 5 of Set 12 | merauke
# Processing Record 6 of Set 12 | teguldet
# Processing Record 7 of Set 12 | haines junction
# Processing Record 8 of Set 12 | caska
# Processing Record 9 of Set 12 | tanout
# Processing Record 10 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 12 | yagodnoye
# Processing Record 12 of Set 12 | santo antonio do sudoeste
# Processing Record 13 of Set 12 | tazovskiy
# Processing Record 14 of Set 12 | bolonchen
# City not found. Skipping...
# Processing Record 15 of Set 12 | lithgow
# Processing Record 16 of Set 12 | khasan
# Processing Record 17 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 12 | port-cartier
# Processing Record 19 of Set 12 | poronaysk
# Processing Record 20 of Set 12 | minatitlan
# Processing Record 21 of Set 12 | luganville
# Processing Record 22 of Set 12 | touba
# Processing Record 23 of Set 12 | mecca
# Processing Record 24 of Set 12 | eyl
# Processing Record 25 of Set 12 | obo
# Processing Record 26 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 12 | atyashevo
# Processing Record 28 of Set 12 | yerbogachen
# Processing Record 29 of Set 12 | acapulco
# Processing Record 30 of Set 12 | bairiki
# Processing Record 31 of Set 12 | sisimiut
# Processing Record 32 of Set 12 | tura
# Processing Record 33 of Set 12 | beni
# Processing Record 34 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 12 | irituia
# Processing Record 36 of Set 12 | paragominas
# Processing Record 37 of Set 12 | preeceville
# Processing Record 38 of Set 12 | fallon
# Processing Record 39 of Set 12 | olinda
# Processing Record 40 of Set 12 | necochea
# Processing Record 41 of Set 12 | port arthur
# Processing Record 42 of Set 12 | isoka
# Processing Record 43 of Set 12 | la ronge
# Processing Record 44 of Set 12 | mayo
# Processing Record 45 of Set 12 | huron
# Processing Record 46 of Set 12 | ploemeur
# Processing Record 47 of Set 12 | north ogden
# Processing Record 48 of Set 12 | guasdualito
# Processing Record 49 of Set 12 | porto santo
# Processing Record 50 of Set 12 | shelburne
# Processing Record 1 of Set 13 | steamboat springs
# Processing Record 2 of Set 13 | saint-denis
# Processing Record 3 of Set 13 | cap malheureux
# Processing Record 4 of Set 13 | fort nelson
# Processing Record 5 of Set 13 | taiobeiras
# Processing Record 6 of Set 13 | le vauclin
# Processing Record 7 of Set 13 | orodara
# Processing Record 8 of Set 13 | sabang
# Processing Record 9 of Set 13 | kindberg
# Processing Record 10 of Set 13 | portsmouth
# Processing Record 11 of Set 13 | apatou
# Processing Record 12 of Set 13 | linjiang
# Processing Record 13 of Set 13 | troitsko-pechorsk
# Processing Record 14 of Set 13 | san carlos de bariloche
# Processing Record 15 of Set 13 | loandjili
# Processing Record 16 of Set 13 | novita
# Processing Record 17 of Set 13 | deniliquin
# Processing Record 18 of Set 13 | mogzon
# Processing Record 19 of Set 13 | hatfield
# Processing Record 20 of Set 13 | longyan
# Processing Record 21 of Set 13 | daru
# Processing Record 22 of Set 13 | rundu
# Processing Record 23 of Set 13 | batemans bay
# Processing Record 24 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 13 | asosa
# Processing Record 26 of Set 13 | omboue
# Processing Record 27 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 13 | okha
# Processing Record 29 of Set 13 | wanning
# Processing Record 30 of Set 13 | mergui
# City not found. Skipping...
# Processing Record 31 of Set 13 | ewo
# Processing Record 32 of Set 13 | havoysund
# Processing Record 33 of Set 13 | freetown
# Processing Record 34 of Set 13 | polyarnyy
# Processing Record 35 of Set 13 | belyy
# Processing Record 36 of Set 13 | altay
# Processing Record 37 of Set 13 | capao bonito
# Processing Record 38 of Set 13 | vaitape
# Processing Record 39 of Set 13 | dmitriyevka
# Processing Record 40 of Set 13 | saint-pierre
# Processing Record 41 of Set 13 | porbandar
# Processing Record 42 of Set 13 | muros
# Processing Record 43 of Set 13 | corinto
# Processing Record 44 of Set 13 | flinders
# Processing Record 45 of Set 13 | tumaco
# Processing Record 46 of Set 13 | kodinsk
# Processing Record 47 of Set 13 | callaway
# Processing Record 48 of Set 13 | goderich
# Processing Record 49 of Set 13 | russell
# Processing Record 50 of Set 13 | kisangani
# Processing Record 1 of Set 14 | san rafael
# Processing Record 2 of Set 14 | svetlogorsk
# Processing Record 3 of Set 14 | ulladulla
# Processing Record 4 of Set 14 | buala
# Processing Record 5 of Set 14 | howard springs
# Processing Record 6 of Set 14 | vao
# Processing Record 7 of Set 14 | ngunguru
# Processing Record 8 of Set 14 | kysyl-syr
# Processing Record 9 of Set 14 | vardo
# Processing Record 10 of Set 14 | seabra
# Processing Record 11 of Set 14 | catuday
# Processing Record 12 of Set 14 | pokhara
# Processing Record 13 of Set 14 | zile
# Processing Record 14 of Set 14 | pajan
# Processing Record 15 of Set 14 | corowa
# Processing Record 16 of Set 14 | leh
# Processing Record 17 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 18 of Set 14 | houlton
# Processing Record 19 of Set 14 | bartica
# Processing Record 20 of Set 14 | grand-santi
# Processing Record 21 of Set 14 | marystown
# Processing Record 22 of Set 14 | jinchang
# Processing Record 23 of Set 14 | salinopolis
# Processing Record 24 of Set 14 | huarmey
# Processing Record 25 of Set 14 | kampen
# Processing Record 26 of Set 14 | oudtshoorn
# Processing Record 27 of Set 14 | grajau
# Processing Record 28 of Set 14 | gavle
# Processing Record 29 of Set 14 | northam
# Processing Record 30 of Set 14 | borovoy
# Processing Record 31 of Set 14 | sao jose dos pinhais
# Processing Record 32 of Set 14 | colac
# Processing Record 33 of Set 14 | xining
# Processing Record 34 of Set 14 | itoman
# Processing Record 35 of Set 14 | camopi
# Processing Record 36 of Set 14 | meulaboh
# Processing Record 37 of Set 14 | mandera
# Processing Record 38 of Set 14 | watsa
# Processing Record 39 of Set 14 | pryluky
# Processing Record 40 of Set 14 | zarubino
# Processing Record 41 of Set 14 | sao jose da coroa grande
# Processing Record 42 of Set 14 | lavrentiya
# Processing Record 43 of Set 14 | woodward
# Processing Record 44 of Set 14 | praia da vitoria
# Processing Record 45 of Set 14 | ketchenery
# City not found. Skipping...
# Processing Record 46 of Set 14 | angoche
# Processing Record 47 of Set 14 | vestmanna
# Processing Record 48 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 14 | iskateley
# Processing Record 50 of Set 14 | ixtapa
# Processing Record 1 of Set 15 | yatou
# Processing Record 2 of Set 15 | faya
# Processing Record 3 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 4 of Set 15 | sandpoint
# Processing Record 5 of Set 15 | huacho
# Processing Record 6 of Set 15 | nioro
# Processing Record 7 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 15 | coihaique
# Processing Record 9 of Set 15 | tommot
# Processing Record 10 of Set 15 | san fernando
# Processing Record 11 of Set 15 | biltine
# Processing Record 12 of Set 15 | poso
# Processing Record 13 of Set 15 | nhulunbuy
# Processing Record 14 of Set 15 | crotone
# Processing Record 15 of Set 15 | reconquista
# Processing Record 16 of Set 15 | filadelfia
# Processing Record 17 of Set 15 | sioux lookout
# Processing Record 18 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 15 | peniche
# Processing Record 20 of Set 15 | pitea
# Processing Record 21 of Set 15 | sakakah
# Processing Record 22 of Set 15 | puerto escondido
# Processing Record 23 of Set 15 | byron bay
# Processing Record 24 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 25 of Set 15 | darnetal
# Processing Record 26 of Set 15 | pevek
# Processing Record 27 of Set 15 | verkhoyansk
# Processing Record 28 of Set 15 | lypnyazhka
# Processing Record 29 of Set 15 | coronel fabriciano
# Processing Record 30 of Set 15 | padang
# Processing Record 31 of Set 15 | kasungu
# Processing Record 32 of Set 15 | severnyy
# Processing Record 33 of Set 15 | ituacu
# Processing Record 34 of Set 15 | primo tapia
# Processing Record 35 of Set 15 | makakilo city
# Processing Record 36 of Set 15 | paysandu
# Processing Record 37 of Set 15 | okhotsk
# Processing Record 38 of Set 15 | utiel
# Processing Record 39 of Set 15 | gambela
# Processing Record 40 of Set 15 | oksfjord
# Processing Record 41 of Set 15 | puerto boyaca
# Processing Record 42 of Set 15 | hammerfest
# Processing Record 43 of Set 15 | shar
# Processing Record 44 of Set 15 | oussouye
# Processing Record 45 of Set 15 | fairlie
# Processing Record 46 of Set 15 | fairbanks
# Processing Record 47 of Set 15 | pujehun
# Processing Record 48 of Set 15 | lar
# Processing Record 49 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 15 | swinoujscie
# Processing Record 1 of Set 16 | bintulu
# Processing Record 2 of Set 16 | belaya gora
# Processing Record 3 of Set 16 | aswan
# Processing Record 4 of Set 16 | lasa
# Processing Record 5 of Set 16 | kerki
# City not found. Skipping...
# Processing Record 6 of Set 16 | perehonivka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
new_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_order]
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Dwarka      IN  22.2394   68.9678     70.00        61           0
# 1   Punta Arenas      CL -53.1500  -70.9167     62.60        34           0
# 2         Pangoa      PE -12.1167  -73.0000     77.18        89         100
# 3  Mar Del Plata      AR -38.0023  -57.5575     64.40        82          90
# 4         Noumea      NC -22.2763  166.4572     78.01        94           0
#
#    Wind Speed Current Description
# 0       12.50           clear sky
# 1       12.66           clear sky
# 2        1.52     overcast clouds
# 3        8.05       moderate rain
# 4        2.30           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
